# %% [markdown]
# # [Título del notebook]
#
# **Objetivo:** [qué se analiza]
#
# **Pregunta:** [pregunta concreta]
#
# **Fuente(s):** [organismo / dataset / fecha de consulta]

# %% [markdown]
# ## 1. Imports y configuración

# %%
import polars as pl
import duckdb
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

# %% [markdown]
# ## 2. Carga de datos

# %%
# df = pl.read_parquet('data/processed/dataset.parquet')
# df.head()

# %% [markdown]
# ## 3. Análisis exploratorio

# %%
# ...

# %% [markdown]
# ## 4. Visualizaciones

# %%
# ...

# %% [markdown]
# ## 5. Conclusiones y limitaciones
#
# - **Conclusión:** ...
# - **Limitaciones:** ...
